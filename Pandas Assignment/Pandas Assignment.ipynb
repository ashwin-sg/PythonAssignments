# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob

# %%
Sales_Jan = pd.read_csv("Sales_January_2019.csv")
Sales_Feb = pd.read_csv("Sales_February_2019.csv")
Sales_Mar = pd.read_csv("Sales_March_2019.csv")
Sales_Apr = pd.read_csv("Sales_April_2019.csv")
Sales_May = pd.read_csv("Sales_May_2019.csv")
Sales_Jun = pd.read_csv("Sales_June_2019.csv")
Sales_Jul = pd.read_csv("Sales_July_2019.csv")
Sales_Aug = pd.read_csv("Sales_August_2019.csv")
Sales_Sep = pd.read_csv("Sales_September_2019.csv")
Sales_Oct = pd.read_csv("Sales_October_2019.csv")
Sales_Nov = pd.read_csv("Sales_November_2019.csv")
Sales_Dec = pd.read_csv("Sales_December_2019.csv")

# %%
print(Sales_Jan.shape)
print(Sales_Feb.shape)
print(Sales_Mar.shape)
print(Sales_Apr.shape)
print(Sales_May.shape)
print(Sales_Jun.shape)
print(Sales_Jul.shape)
print(Sales_Aug.shape)
print(Sales_Sep.shape)
print(Sales_Oct.shape)
print(Sales_Nov.shape)
print(Sales_Dec.shape)
# Out:
# (9723, 6)
# (12036, 6)
# (15226, 6)
# (18383, 6)
# (16635, 6)
# (13622, 6)
# (14371, 6)
# (12011, 6)
# (11686, 6)
# (20379, 6)
# (17661, 6)
# (25117, 6)

# %%
Sales_Jan
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
Sales_Jan['Month']= 'January'
Sales_Feb['Month']= 'February'
Sales_Mar['Month']= 'March'
Sales_Apr['Month']= 'April'
Sales_May['Month']= 'May'
Sales_Jun['Month']= 'June'
Sales_Jul['Month']= 'July'
Sales_Aug['Month']= 'August'
Sales_Sep['Month']= 'Spetember'
Sales_Oct['Month']= 'October'
Sales_Nov['Month']= 'November'
Sales_Dec['Month']= 'December'

# %%
Sales_Jan =  Sales_Jan.loc[Sales_Jan['Price Each'] != 'Price Each']
Sales_Feb =  Sales_Feb.loc[Sales_Feb['Price Each'] != 'Price Each']
Sales_Mar =  Sales_Mar.loc[Sales_Mar['Price Each'] != 'Price Each']
Sales_Apr =  Sales_Apr.loc[Sales_Apr['Price Each'] != 'Price Each']
Sales_May =  Sales_May.loc[Sales_May['Price Each'] != 'Price Each']
Sales_Jun =  Sales_Jun.loc[Sales_Jun['Price Each'] != 'Price Each']
Sales_Jul =  Sales_Jul.loc[Sales_Jul['Price Each'] != 'Price Each']
Sales_Aug =  Sales_Aug.loc[Sales_Aug['Price Each'] != 'Price Each']
Sales_Sep =  Sales_Sep.loc[Sales_Sep['Price Each'] != 'Price Each']
Sales_Oct =  Sales_Oct.loc[Sales_Oct['Price Each'] != 'Price Each']
Sales_Nov =  Sales_Nov.loc[Sales_Nov['Price Each'] != 'Price Each']
Sales_Dec =  Sales_Dec.loc[Sales_Dec['Price Each'] != 'Price Each']

# %%
Sales_Jan.dropna(inplace=True)
Sales_Feb.dropna(inplace=True)
Sales_Mar.dropna(inplace=True)
Sales_Apr.dropna(inplace=True)
Sales_May.dropna(inplace=True)
Sales_Jun.dropna(inplace=True)
Sales_Jul.dropna(inplace=True)
Sales_Aug.dropna(inplace=True)
Sales_Sep.dropna(inplace=True)
Sales_Oct.dropna(inplace=True)
Sales_Nov.dropna(inplace=True)
Sales_Dec.dropna(inplace=True)
# Out:
# <ipython-input-7-4ab315a419ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Jan.dropna(inplace=True)

# %%
Sales_Jan['Quantity Ordered']=Sales_Jan['Quantity Ordered'].astype(int)
Sales_Feb['Quantity Ordered']=Sales_Feb['Quantity Ordered'].astype(int)
Sales_Mar['Quantity Ordered']=Sales_Mar['Quantity Ordered'].astype(int)
Sales_Apr['Quantity Ordered']=Sales_Apr['Quantity Ordered'].astype(int)
Sales_May['Quantity Ordered']=Sales_May['Quantity Ordered'].astype(int)
Sales_Jun['Quantity Ordered']=Sales_Jun['Quantity Ordered'].astype(int)
Sales_Jul['Quantity Ordered']=Sales_Jul['Quantity Ordered'].astype(int)
Sales_Aug['Quantity Ordered']=Sales_Aug['Quantity Ordered'].astype(int)
Sales_Sep['Quantity Ordered']=Sales_Sep['Quantity Ordered'].astype(int)
Sales_Oct['Quantity Ordered']=Sales_Oct['Quantity Ordered'].astype(int)
Sales_Nov['Quantity Ordered']=Sales_Nov['Quantity Ordered'].astype(int)
Sales_Dec['Quantity Ordered']=Sales_Dec['Quantity Ordered'].astype(int)
# Out:
# <ipython-input-8-f97517236904>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Jan['Quantity Ordered']=Sales_Jan['Quantity Ordered'].astype(int)

# %%
Sales_Jan['Price Each']=Sales_Jan['Price Each'].astype(float)
Sales_Feb['Price Each']=Sales_Feb['Price Each'].astype(float)
Sales_Mar['Price Each']=Sales_Mar['Price Each'].astype(float)
Sales_Apr['Price Each']=Sales_Apr['Price Each'].astype(float)
Sales_May['Price Each']=Sales_May['Price Each'].astype(float)
Sales_Jun['Price Each']=Sales_Jun['Price Each'].astype(float)
Sales_Jul['Price Each']=Sales_Jul['Price Each'].astype(float)
Sales_Aug['Price Each']=Sales_Aug['Price Each'].astype(float)
Sales_Sep['Price Each']=Sales_Sep['Price Each'].astype(float)
Sales_Oct['Price Each']=Sales_Oct['Price Each'].astype(float)
Sales_Nov['Price Each']=Sales_Nov['Price Each'].astype(float)
Sales_Dec['Price Each']=Sales_Dec['Price Each'].astype(float)
# Out:
# <ipython-input-9-39d7790290a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Jan['Price Each']=Sales_Jan['Price Each'].astype(float)

# %%
df = pd.concat((Sales_Jan,Sales_Feb,Sales_Mar,Sales_Apr,Sales_May,Sales_Jun,Sales_Jul,Sales_Aug,Sales_Sep,Sales_Oct,
                Sales_Nov,Sales_Dec), ignore_index=True)

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185945   319666    Lightning Charging Cable                 1       14.95
# 185946   319667       AA Batteries (4-pack)                 2        3.84
# 185947   319668             Vareebadd Phone                 1      400.00
# 185948   319669            Wired Headphones                 1       11.99
# 185949   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address     Month
# ...

# %% [markdown]
# #### 1. What was the best sales month? What was the revenue for that month? Draw a chart showing sales for each month

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January

# %%
df1['Sales'] = df1['Quantity Ordered']*df1['Price Each']

# %%
df1.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January   11.99

# %%
df1_sales = df1.groupby('Month')['Sales'].sum().sort_values().round(5)
df1_sales
# Out:
# Month
# January      1815335.12
# Spetember    2098816.70
# February     2203481.24
# August       2244412.31
# June         2578293.30
# July         2646899.69
# March        2809063.30
# May          3144584.80
# November     3198909.23
# April        3396059.11
# October      3736884.05
# December     4619297.12
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(15,5))
df1_sales.plot.bar()

# %% [markdown]
# <h4>Answer: December is the best month with sales revenue of 4619297.12</h4>

# %% [markdown]
# #### 2.What US city has the highest number of sales?

# %%
df2 = df1.copy()

# %%
df2['City'] = df2['Purchase Address'].str.split(",",n=2, expand=True)[1]

# %%
df2.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January   11.99
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# 4          Austin

# %%
df2.groupby('City')['Sales'].sum().sort_values(ascending=False)
# Out:
# City
#  San Francisco    8.262204e+06
#  Los Angeles      5.452571e+06
#  New York City    4.664317e+06
#  Boston           3.661642e+06
#  Atlanta          2.795499e+06
#  Dallas           2.767975e+06
#  Seattle          2.747755e+06
#  Portland         2.320491e+06
#  Austin           1.819582e+06
# Name: Sales, dtype: float64

# %% [markdown]
# <h4>Answer: San Francisco has highest number of sales</h4>

# %% [markdown]
# #### 3. We want to buy paid advertisements on the website to promote our products. What is the best time to maximize the likelihood of customer’s responding to the advertisement and purchasing the product?

# %%
df2['Order_Date_New'] = pd.to_datetime(df2['Order Date'])

# %%
df2.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January   11.99
#
#              City      Order_Date_New
# 0          Boston 2019-01-22 21:25:00
# 1        Portland 2019-01-28 14:15:00
# ...

# %%
df2['Hour'] = df2['Order_Date_New'].dt.hour

df2.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January   11.99
#
#              City      Order_Date_New  Hour
# 0          Boston 2019-01-22 21:25:00    21
# ...

# %%
df2_hours = df2.groupby('Hour')['Quantity Ordered'].count()
df2_hours.plot()

# %% [markdown]
# <h4>Answer: From the above fig. we can conclude that the peak time for maximum orders is around afternoon i.e. 10 to 12 Pm and in evening from 5 to 8 Pm. Hence, that should the time for paid advertisements </h4>

# %% [markdown]
# #### 4. What products are most often bought together by the customer?

# %%
df2['Sold_Together'] = df2.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
df2.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address    Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  January  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  January   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  January   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  January  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  January   11.99
#
#              City      Order_Date_New  Hour             Sold_Together
# ...

# %%
df2 = df2[['Order ID','Sold_Together']].drop_duplicates()

# %%
from itertools import combinations
from collections import Counter

sold_list = Counter()

for prod in df2['Sold_Together']:
    prod_list = prod.split(',')
    sold_list.update(Counter(combinations(prod_list,2)))

# %%
sold_list.most_common(5)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361)]

# %% [markdown]
# <h4>Answer: The most often bought togehter products are iPhone and light charging cable</h4>

# %% [markdown]
# #### 5. Export the data combining all months in one yearly file, and add the month column from dates in the file and make sure that there are no vacant rows in between.

# %%
df2.to_excel("Sales_Report_2019.xlsx")
